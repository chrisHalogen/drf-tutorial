# %% [markdown]
# # Importing External Data

# %%
from django.shortcuts import render

import openpyxl
from django.shortcuts import render
from .models import Student
from django.http import HttpResponse

def index(request):
    return HttpResponse('This is the api home')

def import_students_from_excel(request):

    file_path = "/home/halogen/Documents/demo_django/api_env/myProject/static/students_data.xlsx"
    workbook = openpyxl.load_workbook(file_path)
    sheet = workbook.active

    # Get the fields of the Student model
    model_fields = [field.name for field in Student._meta.get_fields() if field.name != "id"]

    # Iterate over rows and create Student objects
    for row in sheet.iter_rows(min_row=2, values_only=True):
        student_data = dict(zip(model_fields, row))
        print(student_data)
        Student.objects.create(**student_data)

    return HttpResponse("Import completed")

# %% [markdown]
# # Making Requests

# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import requests

def make_http_request(url, method='GET', params=None, data=None, headers=None, auth=None):
    """
    Make an HTTP request and display the response.

    :param url: The URL to send the request to.
    :param method: The HTTP method (e.g., GET, POST, PUT, DELETE).
    :param params: Query parameters as a dictionary.
    :param data: Request payload as a dictionary.
    :param headers: Request headers as a dictionary.
    :param auth: Authentication tuple (username, password) if required.
    """
    try:
        response = requests.request(method, url, params=params, data=data, headers=headers, auth=auth)

        print(f"Request: {method} {url}")
        print(f"Status Code: {response.status_code}")
        print("Headers:")
        for key, value in response.headers.items():
            print(f"    {key}: {value}")

        if response.text:
            print("Response:")
            print(response.text)

    except requests.RequestException as e:
        print(f"An error occurred: {e}")

# Example usage:
url = ""
# make_http_request(url, method='GET')

# %% [markdown]
# # JSON and PYTHON

# %%
import json

json_data_string = '{"name":"John", "age": 25, "city":"New York"}'

loaded_data = json.loads(json_data_string)

print(loaded_data)
# Out:
# {'name': 'John', 'age': 25, 'city': 'New York'}

# %%
py_data = {'name': 'John', 'age': 25, 'city': 'New York'}

json_dumped_data = json.dumps(py_data, indent=2)
print(json_dumped_data)
# Out:
# {
#   "name": "John",
#   "age": 25,
#   "city": "New York"
# }

# %% [markdown]
# # Launching HTTP Requests in Python

# %%
import requests

def make_http_request(url, method='GET', params=None, data=None, headers=None, auth=None):
    """
    Make an HTTP request and display the response.

    :param url: The URL to send the request to.
    :param method: The HTTP method (e.g., GET, POST, PUT, DELETE).
    :param params: Query parameters as a dictionary.
    :param data: Request payload as a dictionary.
    :param headers: Request headers as a dictionary.
    :param auth: Authentication tuple (username, password) if required.
    """
    try:
        response = requests.request(method, url, params=params, data=data, headers=headers, auth=auth)

        print(f"Request: {method} {url}")
        print(f"Status Code: {response.status_code}")
        print("Headers:")
        for key, value in response.headers.items():
            print(f"    {key}: {value}")

        if response.text:
            # print("Response:")
            # print(response.text)
            
            return response.text
        else:
            return None

        
    except requests.RequestException as e:
        print(f"An error occurred: {e}")

# %%
# Example usage:
from pprint import pprint
url = "http://127.0.0.1:8000/api/product/all/"

data = {'description': "Samsung's new variant which goes beyond Galaxy to the Universe",
      'name': 'Samsung Universe 9',
      'price': 1249.0,
      'quantity': 46}


result_json = make_http_request(url, method='POST', data=data)
if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: POST http://127.0.0.1:8000/api/product/all/
# Status Code: 201
# Headers:
#     Date: Fri, 22 Dec 2023 14:59:50 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: OPTIONS, POST, GET
#     X-Frame-Options: DENY
#     Content-Length: 53
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'message': 'Product Created Successfully', 'new_id': 3}

# %%
# Example usage:
from pprint import pprint
url = "http://127.0.0.1:8000/api/product/all/"

data = {'description': "OPPO F19 is officially announced on April 2021.",
      'name': 'OPPOF19',
      'price': 280.0,
      'quantity': 123
       }


result_json = make_http_request(url, method='POST', data=data)
if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: POST http://127.0.0.1:8000/api/product/all/
# Status Code: 201
# Headers:
#     Date: Fri, 22 Dec 2023 15:26:27 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: POST, GET, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 121
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'description': 'OPPO F19 is officially announced on April 2021.',
#  'id': 4,
#  'name': 'OPPOF19',
#  'price': '280.00',
#  'quantity': 123}

# %%
# Example usage:
from pprint import pprint
url = "http://127.0.0.1:8000/api/product/single/4/"

result_json = make_http_request(url, method='GET')

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: GET http://127.0.0.1:8000/api/product/single/4/
# Status Code: 200
# Headers:
#     Date: Fri, 22 Dec 2023 15:28:44 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: PUT, OPTIONS, GET, DELETE
#     X-Frame-Options: DENY
#     Content-Length: 121
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'description': 'OPPO F19 is officially announced on April 2021.',
#  'id': 4,
#  'name': 'OPPOF19',
#  'price': '280.00',
#  'quantity': 123}

# %%
# Example usage:
from pprint import pprint
url = "http://127.0.0.1:8000/api/product/single/1/"

data = {'description': 'OPPO F19 is officially announced on April 2021.',
 'name': 'OPPOF19',
 'price': '73',
 'quantity': 24}

result_json = make_http_request(url, method='GET')

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: GET http://127.0.0.1:8000/api/product/single/1/
# Status Code: 200
# Headers:
#     Date: Fri, 22 Dec 2023 16:42:06 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: GET, PUT, OPTIONS, DELETE
#     X-Frame-Options: DENY
#     Content-Length: 182
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'description': 'An apple mobile which is nothing like apple',
#  'detail_url': '/api/product/single/1/',
#  'name': 'iPhone 9',
#  'on_sale': True,
#  'price': '549.00',
#  'quantity': 94,
#  'sale_price': 439.2}

# %%
# Example usage:
from pprint import pprint
url = "http://127.0.0.1:8000/api/product/single/3/"

result_json = make_http_request(url, method='DELETE')

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: DELETE http://127.0.0.1:8000/api/product/single/3/
# Status Code: 204
# Headers:
#     Date: Fri, 22 Dec 2023 15:12:16 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Vary: Accept, Cookie
#     Allow: OPTIONS, GET, DELETE, PUT
#     X-Frame-Options: DENY
#     Content-Length: 0
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin

# %%
print('PSC 0648, Box 3857\nAPO AA 57241')
# Out:
# PSC 0648, Box 3857
# APO AA 57241

# %%
# Example usage:
from pprint import pprint
url = "http://127.0.0.1:8000/api/query-filters/?page=3"

result_json = make_http_request(url, method='GET')

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: GET http://127.0.0.1:8000/api/query-filters/?page=3
# Status Code: 200
# Headers:
#     Date: Fri, 22 Dec 2023 19:41:03 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: GET, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 977
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# [{'age': 22,
#   'email': 'schneiderstephanie@example.com',
#   'full_name': 'Benjamin Hopkins',
#   'gender': 'M',
#   'gpa': 3.8},
#  {'age': 20,
#   'email': 'vasquezjeffrey@example.org',
#   'full_name': 'Christopher Mccoy',
#   'gender': 'F',
#   'gpa': 2.62},
#  {'age': 21,
#   'email': 'chelseahowell@example.net',
#   'full_name': 'Erin Nielsen',
#   'gender': 'M',
#   'gpa': 3.46},
#  {'age': 20,
#   'email': 'nicholas25@example.net',
#   'full_name': 'Shane Olson',
#   'gender': 'F',
#   'gpa': 3.8},
#  {'age': 21,
# ...

# %%
# Example usage:
from pprint import pprint
url = "http://127.0.0.1:8000/api/student-list/?page=2"

result_json = make_http_request(url, method='GET')

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: GET http://127.0.0.1:8000/api/student-list/?page=2
# Status Code: 200
# Headers:
#     Date: Fri, 22 Dec 2023 20:18:36 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: GET, HEAD, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 1610
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'count': 202,
#  'next': 'http://127.0.0.1:8000/api/student-list/?page=3',
#  'previous': 'http://127.0.0.1:8000/api/student-list/',
#  'results': [{'address': '000 Larry Drive\nLake Johnton, MH 41889',
#               'age': 19,
#               'email': 'bowersmichelle@example.com',
#               'first_name': 'Pamela',
#               'gender': 'M',
#               'gpa': '3.02',
#               'graduation_date': '2024-05-24',
#               'id': 6,
#               'is_active': True,
# ...

# %%
# Example usage:
from pprint import pprint
url = "http://127.0.0.1:8000/api/student-create/"

data = {'address': 'N0 76, UNILAG Street, Lagos Island',
              'age': 32,
              'email': 'main@email.net',
              'first_name': 'Rebecca',
              'gender': 'F',
              'gpa': '4.02',
              'graduation_date': '2026-07-24',
              'is_active': True,
              'last_name': 'Gilbert',
              'major': 'Mathematics',
              'phone_number': '(372)321-180'}

result_json = make_http_request(url, method='POST', data= data)

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: POST http://127.0.0.1:8000/api/student-create/
# Status Code: 201
# Headers:
#     Date: Fri, 22 Dec 2023 20:21:21 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: POST, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 262
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'address': 'N0 76, UNILAG Street, Lagos Island',
#  'age': 32,
#  'email': 'main@email.net',
#  'first_name': 'Rebecca',
#  'gender': 'F',
#  'gpa': '4.02',
#  'graduation_date': '2026-07-24',
#  'id': 203,
#  'is_active': True,
#  'last_name': 'Gilbert',
#  'major': 'Mathematics',
#  'phone_number': '(372)321-180'}

# %%
# Example usage:
from pprint import pprint
url = "http://127.0.0.1:8000/api/student-retrieve/200/"

result_json = make_http_request(url, method='GET')

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: GET http://127.0.0.1:8000/api/student-retrieve/200/
# Status Code: 200
# Headers:
#     Date: Fri, 22 Dec 2023 20:08:52 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: GET, HEAD, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 276
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'address': '06371 Robin Mews Apt. 756\nPort Carlos, VI 63259',
#  'age': 20,
#  'email': 'akirby@example.org',
#  'first_name': 'Leah',
#  'gender': 'M',
#  'gpa': '3.32',
#  'graduation_date': '2024-02-19',
#  'id': 200,
#  'is_active': True,
#  'last_name': 'Farley',
#  'major': 'Actuary',
#  'phone_number': '771.660.0335x499'}

# %%
# Example usage:
from pprint import pprint
url = "http://127.0.0.1:8000/api/product/items/"
# api/product/all/
result_json = make_http_request(url, method='GET')

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: GET http://127.0.0.1:8000/api/product/items/
# Status Code: 200
# Headers:
#     Date: Fri, 22 Dec 2023 20:50:26 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: GET, POST, HEAD, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 465
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'count': 3,
#  'next': None,
#  'previous': None,
#  'results': [{'description': 'An apple mobile which is nothing like apple',
#               'id': 1,
#               'name': 'iPhone 9',
#               'price': '549.00',
#               'quantity': 94},
#              {'description': 'SIM-Free, Model A19211 6.5-inch Super Retina HD '
#                              'display with OLED technology A12 Bionic chip '
#                              'with ...',
#               'id': 2,
#               'name': 'iPhone X',
# ...

# %%
# Example usage:
from pprint import pprint
url = "http://127.0.0.1:8000/api/product/items/"
data = {'description': 'This is a Black Berry Phone',
              'name': 'BB Open and Close',
              'price': '27.00',
              'quantity': 86}
result_json = make_http_request(url, method='POST', data=data)

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: POST http://127.0.0.1:8000/api/product/items/
# Status Code: 201
# Headers:
#     Date: Fri, 22 Dec 2023 20:52:57 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: GET, POST, HEAD, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 109
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'description': 'This is a Black Berry Phone',
#  'id': 5,
#  'name': 'BB Open and Close',
#  'price': '27.00',
#  'quantity': 86}

# %%
# Example usage:
from pprint import pprint
url = "http://127.0.0.1:8000/api/product/items/5/"

data = {
 #    'description': 'This is a Black Berry Mobile Phone',
 # 'name': 'BBOC',
 'price': '67.00',
 'quantity': 22
       }

result_json = make_http_request(url, method='DELETE')

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: PATCH http://127.0.0.1:8000/api/product/items/5/
# Status Code: 200
# Headers:
#     Date: Fri, 22 Dec 2023 20:56:46 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: GET, PUT, PATCH, DELETE, HEAD, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 103
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'description': 'This is a Black Berry Mobile Phone',
#  'id': 5,
#  'name': 'BBOC',
#  'price': '67.00',
#  'quantity': 22}

# %%
# Example usage:
from pprint import pprint
import json
url = "http://127.0.0.1:8000/api/edu/teachers/"

result_json = make_http_request(url, method='GET')

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: GET http://127.0.0.1:8000/api/edu/teachers/
# Status Code: 200
# Headers:
#     Date: Sat, 23 Dec 2023 09:24:06 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: GET, POST, HEAD, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 128
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'count': 3,
#  'next': None,
#  'previous': None,
#  'results': [{'id': 1, 'name': 'Gilbert'},
#              {'id': 2, 'name': 'Samuel'},
#              {'id': 3, 'name': 'Michael'}]}

# %%
# Example usage:
# from pprint import pprint
# import json
url = "http://127.0.0.1:8000/api/edu/teachers/"

data = {'name':'James'}

result_json = make_http_request(url, method='POST', data=data)

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: POST http://127.0.0.1:8000/api/edu/teachers/
# Status Code: 201
# Headers:
#     Date: Sat, 23 Dec 2023 09:25:51 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: GET, POST, HEAD, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 23
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'id': 5, 'name': 'James'}

# %%
# Example usage:

url = "http://127.0.0.1:8000/api/edu/courses/"

result_json = make_http_request(url, method='GET')

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: GET http://127.0.0.1:8000/api/edu/courses/
# Status Code: 200
# Headers:
#     Date: Sat, 23 Dec 2023 10:40:37 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: GET, POST, HEAD, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 490
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'count': 6,
#  'next': 'http://127.0.0.1:8000/api/edu/courses/?page=2',
#  'previous': None,
#  'results': [{'id': 1,
#               'name': 'Numerical Analysic',
#               'teacher': {'id': 2, 'name': 'Samuel'}},
#              {'id': 2,
#               'name': 'Mathematical Methods 2',
#               'teacher': {'id': 4, 'name': 'Ezekiel'}},
#              {'id': 3,
#               'name': 'Introduction to Computer Science',
#               'teacher': {'id': 1, 'name': 'Gilbert'}},
#              {'id': 4,
# ...

# %%
# Example usage:
# from pprint import pprint
# import json
url = "http://127.0.0.1:8000/api/edu/courses/"

data = {
    'name':'Computational Methods',
    'teacher': 3
}

result_json = make_http_request(url, method='POST', data=data)

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: POST http://127.0.0.1:8000/api/edu/courses/
# Status Code: 201
# Headers:
#     Date: Sat, 23 Dec 2023 10:47:31 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: GET, POST, HEAD, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 75
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'id': 9,
#  'name': 'Computational Methods',
#  'teacher': {'id': 3, 'name': 'Michael'}}

# %%
# Example usage:

url = "http://127.0.0.1:8000/api/edu/courses/3/"

result_json = make_http_request(url, method='GET')

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: GET http://127.0.0.1:8000/api/edu/courses/3/
# Status Code: 200
# Headers:
#     Date: Sat, 23 Dec 2023 10:50:35 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: GET, PUT, PATCH, DELETE, HEAD, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 86
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'id': 3,
#  'name': 'Introduction to Computer Science',
#  'teacher': {'id': 1, 'name': 'Gilbert'}}

# %%
# Example usage:

url = "http://127.0.0.1:8000/api/edu/courses/3/"

result_json = make_http_request(url, method='GET')

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: GET http://127.0.0.1:8000/api/edu/courses/3/
# Status Code: 404
# Headers:
#     Date: Sat, 23 Dec 2023 10:53:16 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: GET, PUT, PATCH, DELETE, HEAD, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 23
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'detail': 'Not found.'}

# %%
# Example usage:

url = "http://127.0.0.1:8000/api/accounts/"

data = {
    'username' : 'halogenius',
    'email' : 'halogenius@halogeniu.com',
    'password' : 'asdf:yyylkj'
}

result_json = make_http_request(url, method='POST', data=data)

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: POST http://127.0.0.1:8000/api/accounts/
# Status Code: 201
# Headers:
#     Date: Sat, 23 Dec 2023 11:11:02 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: POST, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 169
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'email': 'halogenius@halogeniu.com',
#  'id': 2,
#  'password': 'pbkdf2_sha256$720000$q5lQWjXHBntwAJChKvBT0R$dh8aJIWjJ+4VzwSsAmCn5siraEjUTRx17aPGiTxR+UI=',
#  'username': 'halogenius'}

# %%
from pprint import pprint
import json
from requests.auth import HTTPBasicAuth

url = "http://127.0.0.1:8000/api/accounts/protected-cbv/"

# data = {
#     'username' : 'halogenius',
#     'email' : 'halogenius@halogeniu.com',
#     'password' : 'asdf:yyylkj'
# }

username = 'halogenius'
password = 'asdf:yyylkj'

result_json = make_http_request(url, method='GET', auth= HTTPBasicAuth(username,password))

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: GET http://127.0.0.1:8000/api/accounts/protected-cbv/
# Status Code: 200
# Headers:
#     Date: Sat, 23 Dec 2023 21:11:28 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept
#     Allow: GET, HEAD, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 68
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'message': 'Hello halogenius, This is a protected Class Based view'}

# %%
from pprint import pprint
import json
from requests.auth import HTTPBasicAuth

url = "http://127.0.0.1:8000/api/accounts/protected-cbv/"

# data = {
#     'username' : 'halogenius',
#     'email' : 'halogenius@halogeniu.com',
#     'password' : 'asdf:yyylkj'
# }

username = 'halogenius'
password = 'asdf:yyylkj'

result_json = make_http_request(url, method='GET', auth= HTTPBasicAuth(username,password))

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)

# %%
from pprint import pprint
import json
from requests.auth import HTTPBasicAuth

url = "http://127.0.0.1:8000/api/accounts/obtain-token/"

data = {
    'username' : 'halogenius',
    # 'email' : 'halogenius@halogeniu.com',
    'password' : 'asdf:yyylkj'
}

username = 'halogenius'
password = 'asdf:yyylkj'

result_json = make_http_request(url, method='POST', data=data)

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: POST http://127.0.0.1:8000/api/accounts/obtain-token/
# Status Code: 200
# Headers:
#     Date: Sat, 23 Dec 2023 21:35:57 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept
#     Allow: POST, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 93
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'message': 'Token Generated Successfully',
#  'token': '86a08be084460cdc983c343fd630daa355c8363a'}

# %%
from pprint import pprint
import json
from requests.auth import HTTPBasicAuth

url = "http://127.0.0.1:8000/api/accounts/login/"

data = {
    'username' : 'halogenius',
    # 'email' : 'halogenius@halogeniu.com',
    'password' : 'asdf:yyylkj'
}

username = 'halogenius'
password = 'asdf:yyylkj'

result_json = make_http_request(url, method='POST', data=data)

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: POST http://127.0.0.1:8000/api/accounts/login/
# Status Code: 200
# Headers:
#     Date: Sat, 23 Dec 2023 21:57:31 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: POST, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 42
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#     Set-Cookie: csrftoken=DZ9nufgJRA7tTt7do7wC1fHhrcHRETEp; expires=Sat, 21 Dec 2024 21:57:31 GMT; Max-Age=31449600; Path=/; SameSite=Lax, sessionid=5d7l2x82ucagrse5bqwy45nike0yha8w; expires=Sat, 06 Jan 2024 21:57:31 GMT; HttpOnly; Max-Age=1209600; Path=/; SameSite=Lax
#
#
# Response Data:
# {'message': 'User Logged out Successfully'}

# %%
from pprint import pprint
import json
from requests.auth import HTTPBasicAuth

url = "http://127.0.0.1:8000/api/accounts/protected-view/"
token = "86a08be084460cdc983c343fd630daa355c8363a"

headers = {
    'Authorization': f"Token {token}"
}

result_json = make_http_request(url, method='GET', headers=headers)

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: GET http://127.0.0.1:8000/api/accounts/protected-view/
# Status Code: 200
# Headers:
#     Date: Sat, 23 Dec 2023 21:41:16 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept
#     Allow: GET, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 56
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'message': 'Hello halogenius, This is a protected view'}

# %%
from pprint import pprint
import json
from requests.auth import HTTPBasicAuth

url = "http://127.0.0.1:8000/api/accounts/protected-view/"

data = {
    'username' : 'halogenius',
    # 'email' : 'halogenius@halogeniu.com',
    'password' : 'asdf:yyylkj'
}

username = 'halogenius'
password = 'asdf:yyylkj'

result_json = make_http_request(url, method='GET', data=data)

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: GET http://127.0.0.1:8000/api/accounts/protected-view/
# Status Code: 403
# Headers:
#     Date: Sat, 23 Dec 2023 22:02:39 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept, Cookie
#     Allow: GET, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 58
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
#
#
# Response Data:
# {'detail': 'Authentication credentials were not provided.'}

# %%
from pprint import pprint
import json
from requests.auth import HTTPBasicAuth

url = "http://127.0.0.1:8000/api/accounts/tokens/"

data = {
    'username' : 'halogenius',
    # 'email' : 'halogenius@halogeniu.com',
    'password' : 'asdf:yyylkj'
}

username = 'halogenius'
password = 'asdf:yyylkj'

result_json = make_http_request(url, method='GET', data=data)

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)

# %%
import requests

# Replace these with your actual authentication details
USERNAME = 'halogenius'
PASSWORD = 'asdf:yyylkj_'

# URL of the session authentication-protected view
url = 'http://127.0.0.1:8000/api/accounts/protected-cbv/'

# Create a session
session = requests.Session()

# Perform login to obtain the session cookie
login_data = {
    'username': USERNAME,
    'password': PASSWORD
}

login_response = session.post('http://127.0.0.1:8000/api/accounts/login/', data=login_data)

# Check if login was successful (you may need to adjust this based on your authentication mechanism)
if login_response.status_code == 200:
    print("Login successful")
else:
    print(f"Login failed with status code: {login_response.status_code}")
    exit()

# Make a request to the protected view using the established session
response = session.get(url)

# Check if the request was successful
if response.status_code == 200:
    print("Request to protected view successful")
    print("Response content:")
    print(response.text)
else:
    print(f"Request failed with status code: {response.status_code}")

# Close the session
session.close()
# Out:
# Login failed with status code: 401
# Request failed with status code: 403

# %%
from pprint import pprint
import json

url = "http://127.0.0.1:8000/api/accounts/token/"

data = {
    'username' : 'halogenius',
    # 'email' : 'halogenius@halogeniu.com',
    'password' : 'asdf:yyylkj'
}

result_json = make_http_request(url, method='POST', data=data)

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: POST http://127.0.0.1:8000/api/accounts/token/
# Status Code: 200
# Headers:
#     Date: Sat, 23 Dec 2023 22:22:09 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept
#     Allow: POST, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 483
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
# Response:
# {"refresh":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoicmVmcmVzaCIsImV4cCI6MTcwMzQ1NjUyOSwiaWF0IjoxNzAzMzcwMTI5LCJqdGkiOiI2ZGQxZTIwNGI0NzY0OWVmYWYyM2E3NDFiZTYwNDQ2ZCIsInVzZXJfaWQiOjJ9.LtiuxiJWVttLJJUmhmhMzWotiXtwLS9izZa75wPJRp8","access":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzAzMzcwNDI5LCJpYXQiOjE3MDMzNzAxMjksImp0aSI6ImNmMDZjMGUwMzU5NTRhYTdiOGQwMGVhNDZmOTkwNGViIiwidXNlcl9pZCI6Mn0.W380ZDfHIqbT0Ix4SfXF3kmeLsWYqI0sEwXoNxPJDPE"}

# %%
from pprint import pprint
import json

url = "http://127.0.0.1:8000/api/accounts/protected-cbv/"
token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzAzMzcwNDI5LCJpYXQiOjE3MDMzNzAxMjksImp0aSI6ImNmMDZjMGUwMzU5NTRhYTdiOGQwMGVhNDZmOTkwNGViIiwidXNlcl9pZCI6Mn0.W380ZDfHIqbT0Ix4SfXF3kmeLsWYqI0sEwXoNxPJDPE"

headers = {
    'Authorization': f"Bearer {token}"
}

result_json = make_http_request(url, method='GET', headers=headers)

# print(result_json)

if result_json:
    result_dict = json.loads(result_json)
    print("\n\nResponse Data:")
    pprint(result_dict)
# Out:
# Request: GET http://127.0.0.1:8000/api/accounts/protected-cbv/
# Status Code: 200
# Headers:
#     Date: Sat, 23 Dec 2023 22:26:04 GMT
#     Server: WSGIServer/0.2 CPython/3.10.12
#     Content-Type: application/json
#     Vary: Accept
#     Allow: GET, HEAD, OPTIONS
#     X-Frame-Options: DENY
#     Content-Length: 68
#     X-Content-Type-Options: nosniff
#     Referrer-Policy: same-origin
#     Cross-Origin-Opener-Policy: same-origin
# Response:
# {"message":"Hello halogenius, This is a protected Class Based view"}
